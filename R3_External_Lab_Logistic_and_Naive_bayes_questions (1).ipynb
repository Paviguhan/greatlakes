# %% [markdown]
# ## Supervised Learning - Building a Student Performace Prediction System

# %% [markdown]
# ## Question 1 - Classification vs. Regression
#
# *The aim of this project is to predict how likely a student is to pass. Which type of supervised learning problem is this, classification or regression? Why?*
#
# #### Answer:
# This project is a classification supervised learning problem because the variable to predict, i.e. if a student graduates or fails to graduate, is categorical. On this case this a dichotomous categorical variable where the only two possible values are "pass" or "fail".

# %% [markdown]
# ### Overview:
#
# 1.Read the problem statement.
#
# 2.Get the dataset.
#
# 3.Explore the dataset.
#
# 4.Pre-processing of dataset.
#
# 5.Transform the dataset for building machine learning model.
#
# 6.Split data into train, test set.
#
# 7.Build Model.
#
# 8.Apply the model.
#
# 9.Evaluate the model.
#
# 10.Provide insights.

# %% [markdown]
# ## Problem Statement
#
# Using Logistic Regression **predict the performance of student**. The classification goal is to predict whether the student will pass or fail.
#
# ## Dataset
#
# This data approach student achievement in secondary education of two Portuguese schools. The data attributes include student grades, demographic, social and school related features) and it was collected by using school reports and questionnaires. Two datasets are provided regarding the performance in Mathematics.
#
# **Source:** https://archive.ics.uci.edu/ml/datasets/Student+Performance

# %% [markdown]
# ## Question 2
# ## Exploring the Data
# *Read the dataset file using pandas. Take care about the delimiter.*
#
# #### Answer:

# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("students-data.csv",delimiter = ";")
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# 5       GP   M   16       U     LE3       T     4     3  services     other
# 6       GP   M   16       U     LE3       T     2     2     other     other
# 7       GP   F   17       U     GT3       A     4     4     other   teacher
# 8       GP   M   15       U     LE3       A     3     2  services     other
# 9       GP   M   15       U     GT3       T     3     4     other     other
# 10      GP   F   15       U     GT3       T     4     4   teacher    health
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
# school        395 non-null object
# sex           395 non-null object
# age           395 non-null int64
# address       395 non-null object
# famsize       395 non-null object
# Pstatus       395 non-null object
# Medu          395 non-null int64
# Fedu          395 non-null int64
# Mjob          395 non-null object
# Fjob          395 non-null object
# reason        395 non-null object
# guardian      395 non-null object
# traveltime    395 non-null int64
# studytime     395 non-null int64
# failures      395 non-null int64
# schoolsup     395 non-null object
# famsup        395 non-null object
# paid          395 non-null object
# activities    395 non-null object
# nursery       395 non-null object
# higher        395 non-null object
# internet      395 non-null object
# romantic      395 non-null object
# famrel        395 non-null int64
# ...

# %% [markdown]
# ## Question 3
# ## Drop missing values
# *Set the index name of the dataframe to **"number"**. Check sample of data to drop if any missing values are there.*
#
# #### Answer:

# %%
df.index.names=["numbers"]
df
# Out:
#         school sex  age address famsize Pstatus  Medu  Fedu      Mjob  \
# numbers
# 0           GP   F   18       U     GT3       A     4     4   at_home
# 1           GP   F   17       U     GT3       T     1     1   at_home
# 2           GP   F   15       U     LE3       T     1     1   at_home
# 3           GP   F   15       U     GT3       T     4     2    health
# 4           GP   F   16       U     GT3       T     3     3     other
# 5           GP   M   16       U     LE3       T     4     3  services
# 6           GP   M   16       U     LE3       T     2     2     other
# 7           GP   F   17       U     GT3       A     4     4     other
# 8           GP   M   15       U     LE3       A     3     2  services
# 9           GP   M   15       U     GT3       T     3     4     other
# 10          GP   F   15       U     GT3       T     4     4   teacher
# 11          GP   F   15       U     GT3       T     2     1  services
# ...

# %%
df.isna().sum()  # No missing values
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %% [markdown]
# ## Transform Data
#
# *Print all the attribute names which are not numerical.*
#
# **Hint:** check **select_dtypes()** and its **include** and **exclude** parameters.**
#
# #### Answer:

# %%
Not_numerical = df.select_dtypes(include=["object"])
Not_numerical
# Out:
#         school sex address famsize Pstatus      Mjob      Fjob      reason  \
# numbers
# 0           GP   F       U     GT3       A   at_home   teacher      course
# 1           GP   F       U     GT3       T   at_home     other      course
# 2           GP   F       U     LE3       T   at_home     other       other
# 3           GP   F       U     GT3       T    health  services        home
# 4           GP   F       U     GT3       T     other     other        home
# 5           GP   M       U     LE3       T  services     other  reputation
# 6           GP   M       U     LE3       T     other     other        home
# 7           GP   F       U     GT3       A     other   teacher        home
# 8           GP   M       U     LE3       A  services     other        home
# 9           GP   M       U     GT3       T     other     other        home
# 10          GP   F       U     GT3       T   teacher    health  reputation
# ...

# %% [markdown]
# ## Drop variables with less variance
#
# *Find the variance of each numerical independent variable and drop whose variance is less than 1.*

# %%
df.var()
# Out:
# age            1.628285
# Medu           1.198445
# Fedu           1.184180
# traveltime     0.486513
# studytime      0.704324
# failures       0.553017
# famrel         0.803997
# freetime       0.997725
# goout          1.239388
# Dalc           0.793420
# Walc           1.658678
# health         1.932944
# absences      64.049541
# G1            11.017053
# G2            14.148917
# G3            20.989616
# dtype: float64

# %%
threshold = 1        
var_df = df.drop(df.var()[df.var() < threshold].index.values, axis=1)
var_df.head(2)
# Out:
#         school sex  age address famsize Pstatus  Medu  Fedu     Mjob     Fjob  \
# numbers
# 0           GP   F   18       U     GT3       A     4     4  at_home  teacher
# 1           GP   F   17       U     GT3       T     1     1  at_home    other
#
#          ... higher internet romantic goout Walc health absences G1 G2 G3
# numbers  ...
# 0        ...    yes       no       no     4    1      3        6  5  6  6
# 1        ...    yes      yes       no     3    1      3        4  5  5  6
#
# [2 rows x 27 columns]

# %% [markdown]
# ## Question 4 - Encode all categorical variables to numerical
#
# Take the list of categorical attributes(from the above result) and convert them into neumerical variables. After that, print the head of dataframe and check the values.
#
# **Hint:** check **sklearn LabelEncoder()**
#
# #### Answer:

# %%
from sklearn.preprocessing import LabelEncoder  # nursery,higher,internet,
lb_students = LabelEncoder()  #"sex","address","famsize","Pstatus","Medu","Fedu","Mjob","Fjob","higher","internet","romantic","goout","Walc","health","absences","G1","G2","G3"
var_df["school_code"] = lb_students.fit_transform(var_df["school"])
var_df[ "school_code"]
var_df["sex_code"] = lb_students.fit_transform(var_df["sex"])
var_df[["sex", "sex_code"]]
var_df["address_code"] = lb_students.fit_transform(var_df["address"])
var_df[["address", "address_code"]]
var_df["famsize_code"] = lb_students.fit_transform(var_df["famsize"])
var_df[["famsize", "famsize_code"]]
var_df["Pstatus_code"] = lb_students.fit_transform(var_df["Pstatus"])
var_df["Pstatus_code"]
var_df["Mjob_code"] = lb_students.fit_transform(var_df["Mjob"])
var_df[["Mjob", "Mjob_code"]]
var_df["Fjob_code"] = lb_students.fit_transform(var_df["Fjob"])
var_df[["Fjob", "Fjob_code"]]
var_df["reason_code"] = lb_students.fit_transform(var_df["reason"])
var_df[["reason", "reason_code"]]
var_df["guardian_code"] = lb_students.fit_transform(var_df["guardian"])
var_df["guardian_code"]
var_df["schoolsup_code"] = lb_students.fit_transform(var_df["schoolsup"])
var_df[["schoolsup", "schoolsup_code"]]
var_df["famsup_code"] = lb_students.fit_transform(var_df["famsup"])
var_df[["famsup", "famsup_code"]]
var_df["paid_code"] = lb_students.fit_transform(var_df["paid"])
var_df[["paid", "paid_code"]]
var_df["activities_code"] = lb_students.fit_transform(var_df["activities"])
var_df[["activities", "activities_code"]]
var_df["nursery_code"] = lb_students.fit_transform(var_df["nursery"])
var_df[["nursery", "nursery_code"]]
var_df["higher_code"] = lb_students.fit_transform(var_df["higher"])
var_df[["higher", "higher_code"]]
var_df["internet_code"] = lb_students.fit_transform(var_df["internet"])
var_df[["internet", "internet_code"]]
var_df["romantic_code"] = lb_students.fit_transform(var_df["romantic"])
var_df[["romantic", "romantic_code"]]
var_df  #the list from above var_df along with their codes are printed below
# Out:
#         school sex  age address famsize Pstatus  Medu  Fedu      Mjob  \
# numbers
# 0           GP   F   18       U     GT3       A     4     4   at_home
# 1           GP   F   17       U     GT3       T     1     1   at_home
# 2           GP   F   15       U     LE3       T     1     1   at_home
# 3           GP   F   15       U     GT3       T     4     2    health
# 4           GP   F   16       U     GT3       T     3     3     other
# 5           GP   M   16       U     LE3       T     4     3  services
# 6           GP   M   16       U     LE3       T     2     2     other
# 7           GP   F   17       U     GT3       A     4     4     other
# 8           GP   M   15       U     LE3       A     3     2  services
# 9           GP   M   15       U     GT3       T     3     4     other
# 10          GP   F   15       U     GT3       T     4     4   teacher
# 11          GP   F   15       U     GT3       T     2     1  services
# ...

# %% [markdown]
# ## Question 5 - Convert the continuous values of grades into classes
#
# *Consider the values in G1, G2 and G3 with >= 10 as pass(1) and < 10 as fail(0) and encode them into binary values. Print head of dataframe to check the values.*
#
# #### Answer:

# %%
var_df["G1"] = pd.DataFrame(np.where(var_df["G1"] >= 10, 1, 0), columns=["G1"])
var_df.head(5)
# Out:
#         school sex  age address famsize Pstatus  Medu  Fedu     Mjob  \
# numbers
# 0           GP   F   18       U     GT3       A     4     4  at_home
# 1           GP   F   17       U     GT3       T     1     1  at_home
# 2           GP   F   15       U     LE3       T     1     1  at_home
# 3           GP   F   15       U     GT3       T     4     2   health
# 4           GP   F   16       U     GT3       T     3     3    other
#
#              Fjob  ... reason_code guardian_code schoolsup_code famsup_code  \
# numbers            ...
# 0         teacher  ...           0             1              1           0
# 1           other  ...           0             0              0           1
# 2           other  ...           2             1              1           0
# 3        services  ...           1             1              0           1
# 4           other  ...           1             0              0           1
#
# ...

# %%
var_df["G2"] = pd.DataFrame(np.where(var_df["G2"] >= 10, 1, 0), columns=["G2"])

# %%
var_df["G3"] = pd.DataFrame(np.where(var_df["G3"] >= 10, 1, 0), columns=["G3"])

# %%
var_df.iloc[:,24:27].head(10)
# Out:
#          G1  G2  G3
# numbers
# 0         0   0   0
# 1         0   0   0
# 2         0   0   1
# 3         1   1   1
# 4         0   1   1
# 5         1   1   1
# 6         1   1   1
# 7         0   0   0
# 8         1   1   1
# 9         1   1   1

# %% [markdown]
# ## Question 6
# *Consider G3 is the target attribute and remaining all attributes as features to predict G3. Now, separate features and target into separate dataframes and name them X and y respectively.*

# %%
X = pd.DataFrame.drop(self = var_df, columns = "G3")
X.head(5)
# Out:
#         school sex  age address famsize Pstatus  Medu  Fedu     Mjob  \
# numbers
# 0           GP   F   18       U     GT3       A     4     4  at_home
# 1           GP   F   17       U     GT3       T     1     1  at_home
# 2           GP   F   15       U     LE3       T     1     1  at_home
# 3           GP   F   15       U     GT3       T     4     2   health
# 4           GP   F   16       U     GT3       T     3     3    other
#
#              Fjob  ... reason_code guardian_code schoolsup_code famsup_code  \
# numbers            ...
# 0         teacher  ...           0             1              1           0
# 1           other  ...           0             0              0           1
# 2           other  ...           2             1              1           0
# 3        services  ...           1             1              0           1
# 4           other  ...           1             0              0           1
#
# ...

# %%
y = var_df["G3"]
y.head(5)
# Out:
# numbers
# 0    0
# 1    0
# 2    1
# 3    1
# 4    1
# Name: G3, dtype: int32

# %% [markdown]
# ## Visualization
#
# ## Question 7
#
# *Plot G2 and G3 and give your understanding on relation between both variables.*

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.mplot3d import axes3d

var_df.plot(x='G3', y='G2', color='c', title='scatter plot : G2 vs G3');

# %% [markdown]
# The G3 depends a great deal on the G2. Thus, the G2 can be a good predictor of the outcome variable.

# %% [markdown]
# ## Question 8
#
# *Plot the number of students in each school and number of students with different ages in separate plots.*

# %%
var_df.school.value_counts()
# Out:
# GP    349
# MS     46
# Name: school, dtype: int64

# %%
var_df.school.value_counts().plot(kind='bar')

# %%
var_df.age.value_counts()
# Out:
# 16    104
# 17     98
# 18     82
# 15     82
# 19     24
# 20      3
# 22      1
# 21      1
# Name: age, dtype: int64

# %%
var_df.age.plot(kind='hist', title='histogram for Age', color='c');

# %%
new = var_df.iloc[:,20:44]
new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 24 columns):
# goout              395 non-null int64
# Walc               395 non-null int64
# health             395 non-null int64
# absences           395 non-null int64
# G1                 395 non-null int32
# G2                 395 non-null int32
# G3                 395 non-null int32
# school_code        395 non-null int32
# sex_code           395 non-null int32
# address_code       395 non-null int32
# famsize_code       395 non-null int32
# Pstatus_code       395 non-null int32
# Mjob_code          395 non-null int32
# Fjob_code          395 non-null int32
# reason_code        395 non-null int32
# guardian_code      395 non-null int32
# schoolsup_code     395 non-null int32
# famsup_code        395 non-null int32
# paid_code          395 non-null int32
# activities_code    395 non-null int32
# nursery_code       395 non-null int32
# higher_code        395 non-null int32
# ...

# %% [markdown]
# ## Question 9 - Training and testing data split

# %% [markdown]
# *So far, you have converted all categorical features into numeric values. Now, split the data into training and test sets with training size of 300 records. Print the number of train and test records.*
#
# **Hint:** check **train_test_split()** from **sklearn**
#
# #### Answer:

# %%
from sklearn.model_selection import train_test_split

# %%
X =  new.drop("G3", axis=1)
y =  new.pop("G3")

train_set, test_set, train_labels, test_labels = train_test_split(X, y, test_size=0.25, random_state=1)

# %% [markdown]
# ## Question 10 - Model Implementation and Testing the Accuracy
#
# *Build a **LogisticRegression** classifier using **fit()** and **predict()** functions in sklearn. Print Accuracy and F1 score of Training and Test sets.*
#
# #### Answer:

# %%
from sklearn import metrics
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(train_set, train_labels)
model_score = model.score(test_set, test_labels)
print(model_score)
test_pred = model.predict(test_set)
print(metrics.confusion_matrix(test_labels, test_pred))
print(metrics.classification_report(test_labels, test_pred))  #Accuracy and F1 score of Test sets.
# Out:
# 0.898989898989899
# [[27  4]
#  [ 6 62]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.87      0.84        31
#            1       0.94      0.91      0.93        68
#
#    micro avg       0.90      0.90      0.90        99
#    macro avg       0.88      0.89      0.88        99
# weighted avg       0.90      0.90      0.90        99
# E:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
model = LogisticRegression()
model.fit(train_set, train_labels)
model_score = model.score(train_set, train_labels)
print(model_score)
test_pred = model.predict(train_set)
print(metrics.confusion_matrix(train_labels, test_pred))
print(metrics.classification_report(train_labels, test_pred))   #Accuracy and F1 score of Training sets.
# Out:
# 0.9256756756756757
# [[ 93   6]
#  [ 16 181]]
#               precision    recall  f1-score   support
#
#            0       0.85      0.94      0.89        99
#            1       0.97      0.92      0.94       197
#
#    micro avg       0.93      0.93      0.93       296
#    macro avg       0.91      0.93      0.92       296
# weighted avg       0.93      0.93      0.93       296
# E:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %% [markdown]
# # Naive bayes with Iris data

# %% [markdown]
# ### Import Iris.csv

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris = pd.read_csv("Iris (3).csv")
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# 5      6            5.4           3.9            1.7           0.4
# 6      7            4.6           3.4            1.4           0.3
# 7      8            5.0           3.4            1.5           0.2
# 8      9            4.4           2.9            1.4           0.2
# 9     10            4.9           3.1            1.5           0.1
# 10    11            5.4           3.7            1.5           0.2
# 11    12            4.8           3.4            1.6           0.2
# 12    13            4.8           3.0            1.4           0.1
# ...

# %% [markdown]
# ### Slice data set for Independent variables and dependent variables
# #### Please note 'Species' is my dependent variables, name it y and independent set data as X

# %%
y = iris.iloc[:,-1]
y.head(5)
# Out:
# 0    Iris-setosa
# 1    Iris-setosa
# 2    Iris-setosa
# 3    Iris-setosa
# 4    Iris-setosa
# Name: Species, dtype: object

# %%
X = iris.iloc[:,1:5]
X.head(5)
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0            5.1           3.5            1.4           0.2
# 1            4.9           3.0            1.4           0.2
# 2            4.7           3.2            1.3           0.2
# 3            4.6           3.1            1.5           0.2
# 4            5.0           3.6            1.4           0.2

# %% [markdown]
# ### Find the distribution of target variable (Class)

# %%
sns.pairplot(iris , diag_kind = "kde", hue="Species")

# %% [markdown]
# ### Plot the distribution of target variable using histogram

# %%
var = iris.drop("Id",axis=1)
var.head(10)
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa
# 5            5.4           3.9            1.7           0.4  Iris-setosa
# 6            4.6           3.4            1.4           0.3  Iris-setosa
# 7            5.0           3.4            1.5           0.2  Iris-setosa
# 8            4.4           2.9            1.4           0.2  Iris-setosa
# 9            4.9           3.1            1.5           0.1  Iris-setosa

# %%
plt.figure(figsize = (10, 7)) 
x = iris.SepalWidthCm 
  
plt.hist(x, bins = 20) 
plt.title("Sepal Width in cm") 
plt.xlabel("Sepal_Width_cm") 
plt.ylabel("Count") 
  
plt.show()

# %%
plt.figure(figsize = (10, 7)) 
x = iris.SepalLengthCm 
  
plt.hist(x, bins = 20) 
plt.title("Sepal Length in cm") 
plt.xlabel("Sepal_Length_cm") 
plt.ylabel("Count") 
  
plt.show()

# %%
plt.figure(figsize = (10, 7)) 
x = iris.PetalLengthCm 
  
plt.hist(x, bins = 20) 
plt.title("Petal Length in cm") 
plt.xlabel("Petal_Length_cm") 
plt.ylabel("Count") 
  
plt.show()

# %%
plt.figure(figsize = (10, 7)) 
x = iris.PetalWidthCm 
  
plt.hist(x, bins = 20) 
plt.title("Petal Width in cm") 
plt.xlabel("Petal_Width_cm") 
plt.ylabel("Count") 
  
plt.show()

# %% [markdown]
# ### Plot Scatter Matrix to understand the distribution of variables and give insights from it( 1 Marks)

# %%
sns.FacetGrid(iris,hue="Species").map(plt.scatter,"SepalLengthCm","SepalWidthCm").add_legend()
plt.show()

# %%
sns.FacetGrid(iris,hue="Species").map(plt.scatter,"PetalLengthCm","PetalWidthCm").add_legend()
plt.show()

# %%
fig, ax = plt.subplots()  
ax.set_xlabel('X')  
ax.set_ylabel('y')  
ax.set_title('Scatter plot between X and Y')  
plt.scatter(x, y, marker='.')  
plt.show()

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(iris, figsize = (10,7), )
plt.show()

# %%
#there is a good relation between Petal length and petal width as they increase exponentially.

# %% [markdown]
# ### Summary Statistics and explain insights for at least 2 variables

# %%
iris.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
#1.The dataset does not contain Nan, 
#2.No.of rows are 150

# %% [markdown]
# ### Correlation among all variables and give your insights

# %%
plt.figure(figsize=(5,5))
sns.heatmap(var.corr(),annot=True)
plt.plot()
# Out:
# []

# %% [markdown]
# ### Split data in Training and Validation in 80:20

# %%
from sklearn.model_selection import train_test_split

X =  iris.drop("Species", axis=1)
y =  iris.pop("Species")

# %%
train_set, test_set, train_labels, test_labels = train_test_split(X, y, test_size=0.20, random_state=1)

# %% [markdown]
# ### Do Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler 

scaler = StandardScaler() 
scaler.fit(iris)
# Out:
# E:\Anaconda\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %% [markdown]
# ### Train and Fit NaiveBayes Model

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(train_set, train_labels)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %% [markdown]
# ### Print Accuracy and Confusion Matrix and Conclude your findings

# %%
model.score(train_set , train_labels)
# Out:
# 0.9916666666666667

# %%
from sklearn import metrics
test_pred = model.predict(test_set)

print(metrics.classification_report(test_labels, test_pred))
print(metrics.confusion_matrix(test_labels, test_pred))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        11
# Iris-versicolor       1.00      1.00      1.00        13
#  Iris-virginica       1.00      1.00      1.00         6
#
#       micro avg       1.00      1.00      1.00        30
#       macro avg       1.00      1.00      1.00        30
#    weighted avg       1.00      1.00      1.00        30
#
# [[11  0  0]
#  [ 0 13  0]
#  [ 0  0  6]]

# %%
#Iris dataset using Naive Bayes is giving 99% accuracy. The accuracy is increased as scaling used.
